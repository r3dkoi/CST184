# %%
#Loading and Inspecting the Data
import pandas as pd
df = pd.read_csv("insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#STEP 2
#Filtering Data Based on Probability (age)
#This is used to explore more meaningful subsets of the data, e.g
#the age and smoker columns can lead to some insight on medical insurance usage

#What's the number in a specific age range?
low_age_range = df[df["age"] < 20]
middle_age_range = df[df["age"] > 50]
high_age_range = df[df["age"] > 60]
print("\n --- \n")
print("Below are the age ranges with medical insurance charges")
print(f"The number of people with medical insurance charges that are equal to or less than the age 20 are: {len(low_age_range)}.")
print(f"The number of people with medical insurance charges that are equal or greater than 50 but below 60 are: {len(middle_age_range)}.")
print(f"The number of people with medical insurance charges that are equal or greater than the age of 60 but below 70 are: {len(high_age_range)}.")

print("\n --- \n")
print("Below are the numbers of smokers vs non-smokers in this dataset")
#Number of smokers and non-smokers in this dataset
yes_smoker = df[df["smoker"] == "yes"]
no_smoker = df[df["smoker"] == "no"]
print(f"The number of smokers in this dataset are: {len(yes_smoker)}.")
print(f"The number of non-smokers in this dataset are: {len(no_smoker)}.")
# Out:
#  ---
#
# Below are the age ranges with medical insurance charges
# The number of people with medical insurance charges that are equal to or less than the age 20 are: 137.
# The number of people with medical insurance charges that are equal or greater than 50 but below 60 are: 356.
# The number of people with medical insurance charges that are equal or greater than the age of 60 but below 70 are: 91.
#
#  ---
#
# Below are the numbers of smokers vs non-smokers in this dataset
# The number of smokers in this dataset are: 274.
# The number of non-smokers in this dataset are: 1064.

# %%
#STEP 3 Comparing Charges by Region
region_avg = df.groupby("region")["charges"].mean().plot(kind='bar')

# %%
#STEP 4 Creating a Histogram
import matplotlib.pyplot as plt

df["charges"].plot(kind="hist", bins=5, edgecolor="black")
plt.title("Histogram of medical insurance charges")
plt.xlabel("Charges")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#STEP 5 Create a Density Plot (KDE)
df["charges"].plot(kind="density", linewidth=2)
plt.title("Density Plot of Charges")
plt.xlabel("Charges")
plt.grid(True)
plt.show()

# %%
#STEP 6 Comparing Distributions via Region
df.groupby("region")["charges"].plot(kind="density", legend=True)
plt.title("Medical insurance charges by Region")
plt.xlabel("Charges")
plt.grid(True)
plt.show()

# %%
#The Histogram tells us that most medical charges are below 20k range.
#The distribution (KDE) graph shows that most of the charges are clustered in southwest and northwest regions.

# %%
# Verification: prints the kernel's Python executable and version
import sys, os
print('sys.executable:', sys.executable)
print('sys.version:', sys.version)
print('cwd:', os.getcwd())
