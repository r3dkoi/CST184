# %%
import pandas as pd

df = pd.read_csv("renewable-share-energy.csv")
df.describe()
# Out:
#               Year   Renewables
# count  6379.000000  6379.000000
# mean   1995.358207    11.118055
# std      17.145077    13.269040
# min    1965.000000     0.000000
# 25%    1981.000000     2.126912
# 50%    1996.000000     6.550673
# 75%    2010.000000    15.007385
# max    2024.000000    86.126360

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6379 entries, 0 to 6378
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Entity      6379 non-null   str
#  1   Code        4539 non-null   str
#  2   Year        6379 non-null   int64
#  3   Renewables  6379 non-null   float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 199.5 KB

# %%
df.isnull()
# Out:
#       Entity   Code   Year  Renewables
# 0      False   True  False       False
# 1      False   True  False       False
# 2      False   True  False       False
# 3      False   True  False       False
# 4      False   True  False       False
# ...      ...    ...    ...         ...
# 6374   False  False  False       False
# 6375   False  False  False       False
# 6376   False  False  False       False
# 6377   False  False  False       False
# 6378   False  False  False       False
#
# [6379 rows x 4 columns]

# %%
df.head(30)
# Out:
#     Entity Code  Year  Renewables
# 0   Africa  NaN  1965    5.419266
# 1   Africa  NaN  1966    5.772398
# 2   Africa  NaN  1967    5.963763
# 3   Africa  NaN  1968    6.605470
# 4   Africa  NaN  1969    7.505726
# 5   Africa  NaN  1970    8.649540
# 6   Africa  NaN  1971    7.689221
# 7   Africa  NaN  1972    8.276323
# 8   Africa  NaN  1973    8.068716
# 9   Africa  NaN  1974    8.736290
# 10  Africa  NaN  1975    8.713099
# 11  Africa  NaN  1976    8.906370
# 12  Africa  NaN  1977    9.280894
# 13  Africa  NaN  1978    9.005293
# 14  Africa  NaN  1979    8.839782
# 15  Africa  NaN  1980    8.006187
# 16  Africa  NaN  1981    7.404695
# 17  Africa  NaN  1982    6.944731
# 18  Africa  NaN  1983    6.091397
# 19  Africa  NaN  1984    5.818251
# 20  Africa  NaN  1985    6.217809
# 21  Africa  NaN  1986    6.357194
# 22  Africa  NaN  1987    5.898800
# 23  Africa  NaN  1988    6.009116
# 24  Africa  NaN  1989    6.295899
# 25  Africa  NaN  1990    6.214663
# ...

# %%
df
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa       NaN  1965    5.419266
# 1     Africa       NaN  1966    5.772398
# 2     Africa       NaN  1967    5.963763
# 3     Africa       NaN  1968    6.605470
# 4     Africa       NaN  1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
df.drop_duplicates()
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa       NaN  1965    5.419266
# 1     Africa       NaN  1966    5.772398
# 2     Africa       NaN  1967    5.963763
# 3     Africa       NaN  1968    6.605470
# 4     Africa       NaN  1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
df.drop_duplicates()
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa       NaN  1965    5.419266
# 1     Africa       NaN  1966    5.772398
# 2     Africa       NaN  1967    5.963763
# 3     Africa       NaN  1968    6.605470
# 4     Africa       NaN  1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
df[["Code"]]
# Out:
#           Code
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 6374  OWID_WRL
# 6375  OWID_WRL
# 6376  OWID_WRL
# 6377  OWID_WRL
# 6378  OWID_WRL
#
# [6379 rows x 1 columns]

# %%
df.fillna("")
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa            1965    5.419266
# 1     Africa            1966    5.772398
# 2     Africa            1967    5.963763
# 3     Africa            1968    6.605470
# 4     Africa            1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
df
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa       NaN  1965    5.419266
# 1     Africa       NaN  1966    5.772398
# 2     Africa       NaN  1967    5.963763
# 3     Africa       NaN  1968    6.605470
# 4     Africa       NaN  1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
df.fillna("")
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa            1965    5.419266
# 1     Africa            1966    5.772398
# 2     Africa            1967    5.963763
# 3     Africa            1968    6.605470
# 4     Africa            1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
df = df.fillna("")

# %%
df
# Out:
#       Entity      Code  Year  Renewables
# 0     Africa            1965    5.419266
# 1     Africa            1966    5.772398
# 2     Africa            1967    5.963763
# 3     Africa            1968    6.605470
# 4     Africa            1969    7.505726
# ...      ...       ...   ...         ...
# 6374   World  OWID_WRL  2020   12.780913
# 6375   World  OWID_WRL  2021   12.861119
# 6376   World  OWID_WRL  2022   13.503552
# 6377   World  OWID_WRL  2023   13.942838
# 6378   World  OWID_WRL  2024   14.822139
#
# [6379 rows x 4 columns]

# %%
filtered_countries_with_70 = df[(df["Renewables"] > 70)]

# %%
filtered_countries_with_70
# Out:
#        Entity Code  Year  Renewables
# 2230  Iceland  ISL  2006   70.760090
# 2231  Iceland  ISL  2007   74.337230
# 2232  Iceland  ISL  2008   81.016396
# 2233  Iceland  ISL  2009   82.491196
# 2234  Iceland  ISL  2010   83.047000
# 2235  Iceland  ISL  2011   83.319580
# 2236  Iceland  ISL  2012   83.698906
# 2237  Iceland  ISL  2013   83.281105
# 2238  Iceland  ISL  2014   83.011840
# 2239  Iceland  ISL  2015   82.168380
# 2240  Iceland  ISL  2016   80.356990
# 2241  Iceland  ISL  2017   79.303200
# 2242  Iceland  ISL  2018   78.699590
# 2243  Iceland  ISL  2019   80.843070
# 2244  Iceland  ISL  2020   86.126360
# 2245  Iceland  ISL  2021   84.494316
# 2246  Iceland  ISL  2022   82.075330
# 2247  Iceland  ISL  2023   81.843285
# 2248  Iceland  ISL  2024   80.498090
# 3682   Norway  NOR  1983   70.601530
# 3688   Norway  NOR  1989   70.149796
# 3689   Norway  NOR  1990   71.557940
# 3690   Norway  NOR  1991   70.178980
# 3691   Norway  NOR  1992   71.026276
# ...

# %%
import matplotlib.pyplot as plt

filtered_countries_with_70.plot(x="Entity", y="Renewables", kind="bar", legend=False)
plt.title("Countries with share of primary energy consumption from renewable sources above 70")
plt.ylabel("Tonnes")
plt.show()
