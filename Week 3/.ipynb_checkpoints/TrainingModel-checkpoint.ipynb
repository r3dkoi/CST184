# %%
import pandas as pd

df = pd.read_csv("sample_energy.csv")
df["Apply_Policy"] = df["Apply_Policy"].map({"yes": 1, "no": 0}) #Converts the policy label into a numeric format, 
                                                                #allowing the model to learn from binary outputs.
