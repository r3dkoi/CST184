# %%
"""You work for a global sustainability agency. You’re creating a simple tool that classifies countries based on two indicators:
• % Renewable energy use – indicator of clean energy adoption
• CO₂ emissions (tonnes per capita) – indicator of sustainability pressure
You will simulate a decision tree that outputs one of the following policy classifications:
• "Policy A" – High renewable use and low CO₂
• "Policy B" – High renewable use only
• "Policy C" – Low renewable use but low emissions
• "No Policy" – Neither condition met"""
# Out:
# 'You work for a global sustainability agency. You’re creating a simple tool that classifies countries based on two indicators:\n• % Renewable energy use – indicator of clean energy adoption\n• CO₂ emissions (tonnes per capita) – indicator of sustainability pressure\nYou will simulate a decision tree that outputs one of the following policy classifications:\n• "Policy A" – High renewable use and low CO₂\n• "Policy B" – High renewable use only\n• "Policy C" – Low renewable use but low emissions\n• "No Policy" – Neither condition met'

# %%
# Manual simulation of a decision tree
# Example country data (change values to test different paths)
country = "Bhutan"
percent_renewable = 85
co2_emissions = 1.1

# Simulated decision tree structure
if percent_renewable > 50:
    if co2_emissions < 2:
        classification = "Policy A"
    else:
        classification = "Policy B"
else:
    if co2_emissions < 2:
        classification = "Policy C"
    else:
        classification = "No Policy"
# Output the result
print(f"{country} is classified under: {classification}")
# Out:
# Bhutan is classified under: Policy A

# %%
# Show decision path
print("\n--- Decision Path ---")
print("High Renewable:", percent_renewable > 50)
print("Low CO₂ Emissions:", co2_emissions < 2)
# Out:
# --- Decision Path ---
# High Renewable: True
# Low CO₂ Emissions: True

# %%
"""Changing percent_renewable to 45 and high co2 emissions"""
country = "Philippines"
percent_renewable = 45
co2_emissions = 5.5
# Simulated decision tree structure
if percent_renewable > 50:
    if co2_emissions < 2:
        classification = "Policy A"
    else:
        classification = "Policy B"
else:
    if co2_emissions < 2:
        classification = "Policy C"
    else:
        classification = "No Policy"
# Output the result
print(f"{country} is classified under: {classification}")
# Out:
# Philippines is classified under: No Policy

# %%
"""Adding new policy, 
Policy D = "Flag for urgent review. Extremely high CO2 emissions, and low renewable usage."
region = "Europe"
country = "France"
percent_renewable = 45
co2_emissions = 8.0
# Simulated decision tree structure
if percent_renewable > 50:
    if co2_emissions < 2:
        classification = "Policy A"
    else: 
        classification = "Policy B"
else:
    if co2_emissions < 2:
        classification = "Policy C"
    if co2_emissions > 6:
        if region == "Europe":
            classification = "Policy D"
    else:
        classification = "No Policy"
# Output the result
print(f"{country} is classified under: {classification}")

print("\n--- Decision Path ---")
print("High Renewable:", percent_renewable > 50)
print("Low CO₂ Emissions:", co2_emissions < 2)
print("Region:",
# Out:
# France is classified under: No Policy
#
# --- Decision Path ---
# High Renewable: False
# Low CO₂ Emissions: False
# Region: Oceania

# %%
"""Adding new policy, 
Policy D = "Flag for urgent review. Extremely high CO2 emissions, and low renewable usage, and checks if it's in the region of Europe."""

region = "Oceania"
country = "France"
percent_renewable = 45
co2_emissions = 8.0
# Simulated decision tree structure
if percent_renewable > 50:
    if co2_emissions < 2:
        classification = "Policy A"
    else: 
        classification = "Policy B"
else:
    if co2_emissions < 2:
        classification = "Policy C"
    if co2_emissions > 6 and region == "Europe":
            classification = "Policy D"
    else:
        classification = "No Policy"
# Output the result
print(f"{country} is classified under: {classification}")

print("\n--- Decision Path ---")
print("High Renewable:", percent_renewable > 50)
print("Low CO₂ Emissions:", co2_emissions < 2)
# Out:
# France is classified under: No Policy
#
# --- Decision Path ---
# High Renewable: False
# Low CO₂ Emissions: False
