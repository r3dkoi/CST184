# %%
#Scenario: Apply logic-based policy rules to simulated country data

country = "Kenya"
percent_renewable = 55 # % of energy from renewables
co2_emissions = 1.6 #Tonnes per capita
region = "Africa"
is_low_income = True

#Inference Rule (Modus Ponens style) A -> B then A is TRUE:
#If renewable > 50 and emissions < 2, then country qualifies for Policy A
if percent_renewable > 50 and co2_emissions < 2:
    print(f"{country} qualifies for Policy A.")
else:
    print(f"{country} does not qualify for Policy A.")

#Inference Chain:
#If Policy A applies and the country is in Africa OR is low income, flag for fast-track aid
if percent_renewable > 50 and co2_emissions < 2:
   if region == "Africa" or is_low_income:
       print(f"{country} should be fast-tracked for funding support.")

#Explain the logic in Boolean Values
print("\n-- Truth Table Output ---")
print("High Renewable:", percent_renewable > 50)
print("High Renewable:", percent_renewable > 50)
print("Low Emissions:", co2_emissions < 2)
print("Is in Africa:", region == "Africa")
print("Is Low Income:", is_low_income)
# Out:
# Kenya qualifies for Policy A.
# Kenya should be fast-tracked for funding support.
#
# -- Truth Table Output ---
# High Renewable: True
# High Renewable: True
# Low Emissions: True
# Is in Africa: True
# Is Low Income: True

# %%
#Imagine that Policy B applies to countries with either:
#• More than 60% renewables and located in Africa
#• OR less than 1.5 tonnes CO₂ emissions and classified as low income

#write the condition to flag a country for Policy B using or and and combinations

# %%
country_name_two = "Zimbabwe"
percent_renewable_two = 70 #%
co2_emissions_two = 0.5 #Tonnes

#If renewable > 50 and emissions < 2, then country qualifies for Policy B
if percent_renewable_two > 50 and co2_emissions_two < 1.5:
    print(f"{country_name_two} qualifies for Policy B.")
else:
    print(f"{country_name_two} does not qualify for Policy B.")

#Using Inference Chain 
if percent_renewable_two > 50 and co2_emissions_two < 1.5:
    if region == "Africa" or is_low_income:
        print(f"{country_name_two} should be fast-tracked for funding support.")

#Testing NOT combination
if percent_renewable_two > 50 and not co2_emissions_two > 1.5:
        print(f"{country_name_two} still qualifies for Policy B.")
else:
    print(f"{country_name_two} does not qualify for Policy B.")
# Out:
# Zimbabwe qualifies for Policy B.
# Zimbabwe should be fast-tracked for funding support.
# Zimbabwe still qualifies for Policy B.
