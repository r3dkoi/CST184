# %%
#Scenario:
#Policy A is designed to reward countries with high renewable energy use
# and low CO₂ emissions per capita.

#Country data (you can modify these values below)
country_name = "Nepal"
percent_renewable = 30
co2_emissions = 1.8
region = "Asia"

#Define logical conditions
is_high_renewable = percent_renewable > 50
is_low_emission = co2_emissions < 2
is_not_oceania = region != "Oceania"

#Combined logical proposition using OR
if is_high_renewable or is_low_emission:
    print(f"{country_name} qualifies for Policy A")
else:
    print(f"{country_name} does not qualify for Policy A")

#Display Boolean values for learning
print("High Renewable:", is_high_renewable)
print("Low Emission:", is_low_emission)
print("Not Oceania:", is_not_oceania)
# Out:
# Nepal qualifies for Policy A
# High Renewable: False
# Low Emission: True
# Not Oceania: True

# %%
#Suppose Policy B applies to any country that is not in Europe and uses more than 40% renewable energy. How would you express
#that rule using (and) and not?

# %%
country_name_two= "Indonesia"
percent_renewable_two= 40

#Define logical conditions
is_not_europe = region!= "Europe" 
is_europe = region == "Europe"
medium_renewable = percent_renewable_two >= 40

#Combined logical proposition using OR
if medium_renewable and is_not_europe: #Because if both are true, then the answer is true 
    print(f"{country_name_two} qualifies for Policy B")
else:
    print(f"{country_name_two} does not qualify for Policy B")
# Out:
# Indonesia qualifies for Policy B

# %%
#Combined logical prosition using NOT
low_renewable = percent_renewable_two > 50
if medium_renewable and not is_europe: #If both are true, the variable being subjected after the NOT operator becomes false!
    print(f"{country_name_two} qualifies for Policy B")
else:
    print(f"{country_name_two} does not qualify for Policy B")
# Out:
# Indonesia qualifies for Policy B
