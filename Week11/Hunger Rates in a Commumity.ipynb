# %%
#Prior: Beliefs before seeing the new data
#Likelihood: How well the data supports a possible outcome
#Posterior: Revised belief after combining prior and data

#Formula
#Posterior = (Likelihood x Prior) / Evidence

# %%
#What was observed
successes <- 35
total <- 50

#Parameters
prior <- 0.60 #Bayesian model lets you input a prior belief yourself
likelihood <- 35/50 #P(data | hypothesis) = observed success rate = 0.70
evidence <- 35/50 

#Formula
posterior <- (likelihood * prior_belief) / evidence
posterior
# Out:
# [1] 0.6
